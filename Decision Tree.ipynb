# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.0-cp311-cp311-win_amd64.whl (8.2 MB)
#      ---------------------------------------- 8.2/8.2 MB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\santhosh kumar\python3\lib\site-packages (from scikit-learn) (1.24.0)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp311-cp311-win_amd64.whl (39.9 MB)
#      ---------------------------------------- 39.9/39.9 MB 4.7 MB/s eta 0:00:00
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.0 scipy-1.9.3 threadpoolctl-3.1.0

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.2-cp311-cp311-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 3.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp311-cp311-win_amd64.whl (163 kB)
#      -------------------------------------- 163.6/163.6 kB 3.3 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      -------------------------------------- 965.4/965.4 kB 4.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.4/55.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in c:\users\santhosh kumar\python3\lib\site-packages (from matplotlib) (1.24.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\santhosh kumar\python3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\santhosh kumar\python3\lib\site-packages (from matplotlib) (9.3.0)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\santhosh kumar\python3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\santhosh kumar\python3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.6 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.2 pyparsing-3.0.9

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
p=pd.read_csv('iris.csv')

# %%
p
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
feature_cols=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
x=p[feature_cols]
y=p.Species

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
cm
# Out:
# array([[20,  0,  0],
#        [ 0, 27,  2],
#        [ 0,  0, 26]], dtype=int64)

# %%
ac
# Out:
# 0.9733333333333334

# %%
from sklearn import tree
tree.plot_tree(classifier,feature_names=feature_cols)
# Out:
# [Text(0.375, 0.9, 'PetalWidthCm <= -0.409\ngini = 0.659\nsamples = 75\nvalue = [30, 21, 24]'),
#  Text(0.25, 0.7, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]'),
#  Text(0.5, 0.7, 'PetalWidthCm <= 0.677\ngini = 0.498\nsamples = 45\nvalue = [0, 21, 24]'),
#  Text(0.25, 0.5, 'PetalLengthCm <= 0.756\ngini = 0.165\nsamples = 22\nvalue = [0, 20, 2]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 20\nvalue = [0, 20, 0]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.75, 0.5, 'PetalLengthCm <= 0.701\ngini = 0.083\nsamples = 23\nvalue = [0, 1, 22]'),
#  Text(0.625, 0.3, 'SepalWidthCm <= 0.065\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20]')]

# %%
clas=DecisionTreeClassifier(criterion='entropy',max_depth=2)
clas.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2)

# %%
y_pred=clas.predict(x_test)

# %%
from sklearn import tree
tree.plot_tree(clas,feature_names=feature_cols)
# Out:
# [Text(0.4, 0.8333333333333334, 'PetalWidthCm <= -0.409\nentropy = 1.569\nsamples = 75\nvalue = [30, 21, 24]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 30\nvalue = [30, 0, 0]'),
#  Text(0.6, 0.5, 'PetalWidthCm <= 0.677\nentropy = 0.997\nsamples = 45\nvalue = [0, 21, 24]'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.439\nsamples = 22\nvalue = [0, 20, 2]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.258\nsamples = 23\nvalue = [0, 1, 22]')]
